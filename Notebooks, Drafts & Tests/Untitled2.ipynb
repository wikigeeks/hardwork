# %%
import os

def tryer(fn,d):
    try:
        d0=fn[:-9]+" -> "+d.split("weight |")[1].split('"')[0]
    except:
        d0=None
    finally:
        return d0

for r, d, f in os.walk('0'):
    pass
u=[]
for fn in f:
    s="0\\"+fn
    with open(s,encoding="utf-8") as f1:
        d=f1.read()
        d0=tryer(fn,d)
        if d0:
           u+=[d0.split("&#10;")[0]]

with open("wolfram_result.txt","w",encoding="utf-8") as f2:
    f2.write('\n'.join(u))

# %%
print(len(u))
u
# Out:
# 107
# ['Aepypodius arfakianus ->  1.5 kg (kilograms)',
#  'Agelastes meleagrides ->  810 grams',
#  'Agelastes niger ->  700 grams',
#  'Androdon aequatorialis ->  7.3 grams',
#  'Anorrhinus galeritus ->  1.2 kg (kilograms)',
#  'Anorrhinus tickelli ->  720 grams',
#  'Aphantochroa cirrochloris ->  7.7 grams',
#  'Basilinna leucotis ->  3.6 grams',
#  'Basilinna xantusii ->  3.5 grams',
#  'Bycanistes brevis ->  1.1 kg (kilograms)',
#  'Bycanistes bucinator ->  620 grams',
#  'Bycanistes cylindricus ->  920 grams',
#  'Bycanistes fistulator ->  620 grams',
#  'Callipepla douglasii ->  180 grams',
#  'Caloperdix oculea ->  190 grams',
#  'Chordeiles acutipennis ->  50 grams',
#  'Chordeiles gundlachii ->  79 grams',
#  'Chordeiles minor ->  (65 to 98) grams',
#  'Chordeiles pusillus ->  31 grams',
#  'Chrysuronia oenone ->  5 grams',
#  'Clytolaema rubricauda ->  7.9 grams',
#  'Colinus cristatus ->  140 grams',
#  'Colinus leucopogon ->  140 grams',
# ...
